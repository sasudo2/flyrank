# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# Lane 1 : Ranking Signal Analysis

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# The output of this lane does't produce a ranking itself, it produces evidence that informs other decisions. It improves strategic content decisions and future model design choices.
#
# There are two main actors on findings from this lane. First the SEO/Content strategists who can directly use the findings from this lane into the the page for better engagement and second the ML engineer who can now more confidently decide which features go into a scoring model.
#
# It has a high wrong recommendation cost as a wrong recommendation from this work leads to both SEO team and ML team towards focusing their effort into wrong set of parameters which will waste their effort and produce no result at best case and produce the opposite result at worst case.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("../../data/raw/content_refresh_anonymized.csv")

# 1. How many pages are actually declining?
decline_rate = (df["trend_direction"] == "down").mean()
print(f"Share of content declining: {decline_rate:.1%}")

# 2. Does position correlate with CTR the way you'd expect?
corr = df["avg_position"].corr(df["ctr"])
print(f"Correlation (avg_position vs ctr): {corr:.3f}")

# 3. Is there a real gap between high and low freshness in visibility?
by_freshness = df.groupby("freshness_tier")["impressions_90d"].median()
print(by_freshness)

print("if freshness = better visibility we would expect a smooth decline as content ages, but we see a peak around 91-180 days then a sharp decline afterwards")
# Out:
# Share of content declining: 54.2%
# Correlation (avg_position vs ctr): -0.073
# freshness_tier
# 0-30       470.0
# 181+        15.5
# 31-90      510.0
# 91-180    1692.0
# Name: impressions_90d, dtype: float64
# if freshness = better visibility we would expect a smooth decline as content ages, but we see a peak around 91-180 days then a sharp decline afterwards

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# What My Work CAN Say
#
# - Observed associations between signals and outcomes, within this dataset
# - Correlation strength and direction, with effect size stated honestly
# - Directional patterns ("tends to," "appears to," "more/less associated with")
# - Which signals look worth building into a future scoring model, and which don't
# - Findings framed as decision-support for human review — not automated action
#
# What My Work Will NEVER Say
#
# - No causal claims — correlation is not causation
# - No claims about Google's ranking algorithm
# - No claims that an action (like refreshing a page) will fix or improve performance, without a real experiment
# - No generalizing beyond the sample, clients, or time window studied
# - No treating weak correlations as meaningful findings
# - No presenting a pattern as certainty rather than evidence

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
